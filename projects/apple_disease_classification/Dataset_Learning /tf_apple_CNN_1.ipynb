# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
from PIL import Image
import io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from sklearn.model_selection import train_test_split
import random
import requests
import scipy as sp
import tensorflow as tf
import tensorflow.keras as keras
import zipfile
import pathlib

import pandas as pd
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import datetime

# %%
os.environ['TF_CPP_MIN_LEVEL'] = '0'
np.set_printoptions(precision=3, suppress=True)

# %%
test_data_dir = '../data/Test'
appleDirectory = '../data/Train'
data_dir = pathlib.Path(appleDirectory)
edgeFiles = list()

for filename in os.listdir(appleDirectory):
    imgAppleDirectory = os.path.join(appleDirectory, filename)
    edgeFiles.append(imgAppleDirectory)
    # print(edgeFiles)

# %%
edgeFiles = [img for img in edgeFiles if ".jpg" in img]
# print(type(edgeFiles))
# print(edgeFiles[0])

# %%
batch_size = 32
img_height = 360
img_width = 360

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 382 files belonging to 4 classes.
# Using 306 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 382 files belonging to 4 classes.
# Using 76 files for validation.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_data_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 120 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
test_label = test_ds.class_names

# %%
# augmentation toegevoegen
data_augmentation = keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical", input_shape=(img_height, img_width,3)),
  layers.RandomRotation(45.5),
])

# %%
# augmentation toegevoegen
image, label = next(iter(train_ds))

# %%
# augmentation toegevoegen
image = tf.cast(tf.expand_dims(image, 0), tf.float32)

# %%
# plt.figure(figsize=(10, 10))
# for images, labels in train_ds.take(1):
#     for i in range(16):
#         augmented_image = data_augmentation(images, training = True)
#         ax = plt.subplot(4, 4, i + 1)
#         plt.imshow(augmented_image[i].numpy().astype("uint8"))
#         plt.title(class_names[labels[i]])
#         plt.axis("off")

# %%
num_classes = len(class_names)

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(rate=0.2 ),  
  layers.Flatten(),
  layers.Dense(32, activation='relu'),
  layers.Dense(32, activation='relu'),
  layers.Dense(64, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_10 (Sequential)  (None, 360, 360, 3)       0
#
#  rescaling_3 (Rescaling)     (None, 360, 360, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 360, 360, 16)      448
#
#  max_pooling2d_9 (MaxPooling  (None, 180, 180, 16)     0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 180, 180, 32)      4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 90, 90, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 90, 90, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 45, 45, 64)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 45, 45, 64)        0
#
#  flatten_3 (Flatten)         (None, 129600)            0
#
#  dense_12 (Dense)            (None, 32)                4147232
#
#  dense_13 (Dense)            (None, 32)                1056
#
#  dense_14 (Dense)            (None, 64)                2112
#
#  dense_15 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 4,174,244
# Trainable params: 4,174,244
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[tensorboard_callback])
# Out:
# Epoch 1/15
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 10/10 [==============================] - 19s 2s/step - loss: 2.1379 - accuracy: 0.2549 - val_loss: 1.3741 - val_accuracy: 0.2368
# Epoch 2/15
# 10/10 [==============================] - 16s 2s/step - loss: 1.3322 - accuracy: 0.3431 - val_loss: 1.2921 - val_accuracy: 0.2368
# Epoch 3/15
# 10/10 [==============================] - 17s 2s/step - loss: 1.2038 - accuracy: 0.4477 - val_loss: 1.0888 - val_accuracy: 0.4605
# Epoch 4/15
# 10/10 [==============================] - 17s 2s/step - loss: 1.0616 - accuracy: 0.5621 - val_loss: 1.0138 - val_accuracy: 0.5263
# Epoch 5/15
# 10/10 [==============================] - 17s 2s/step - loss: 1.0363 - accuracy: 0.5850 - val_loss: 0.9343 - val_accuracy: 0.5526
# Epoch 6/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.9568 - accuracy: 0.6242 - val_loss: 0.8918 - val_accuracy: 0.5921
# Epoch 7/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.9017 - accuracy: 0.6438 - val_loss: 0.9665 - val_accuracy: 0.5921
# Epoch 8/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.8751 - accuracy: 0.6601 - val_loss: 0.8967 - val_accuracy: 0.6316
# Epoch 9/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.8813 - accuracy: 0.6405 - val_loss: 0.8352 - val_accuracy: 0.6053
# Epoch 10/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.7934 - accuracy: 0.6765 - val_loss: 0.9482 - val_accuracy: 0.5789
# Epoch 11/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.9303 - accuracy: 0.6242 - val_loss: 0.9085 - val_accuracy: 0.6053
# Epoch 12/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.8269 - accuracy: 0.6863 - val_loss: 0.8652 - val_accuracy: 0.6053
# Epoch 13/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.8179 - accuracy: 0.6830 - val_loss: 0.8851 - val_accuracy: 0.5921
# Epoch 14/15
# 10/10 [==============================] - 17s 2s/step - loss: 0.7584 - accuracy: 0.7190 - val_loss: 0.8053 - val_accuracy: 0.6184
# Epoch 15/15
# 10/10 [==============================] - 16s 2s/step - loss: 0.7362 - accuracy: 0.7124 - val_loss: 0.8110 - val_accuracy: 0.6579

# %%
# Tensorboard
log_dir = "logs/fit" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from keras.models import load_model

model.save('saved_models/appleModel_06.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(34, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
plt.savefig('saved_models/appleModel_06.png')

# %%
# confusion matrix

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

batchPredictions = model.predict(test_ds)
predicted_categories = tf.argmax(batchPredictions, axis=1)
true_categories = tf.concat([y for x, y in test_ds], axis=0)

# confusion_matrix(predicted_categories, true_categories)

confusion_matrix = confusion_matrix(true_categories, predicted_categories)

cm_display = ConfusionMatrixDisplay(confusion_matrix = confusion_matrix,display_labels = ['Blotch_Apple', 'Normal_Apple', 'Rot_Apple', 'Scab_Apple'])



cm_display.plot()

plt.show()
# Out:
# 4/4 [==============================] - 2s 435ms/step

# %%
# %tensorboard --logdir logs/
# Out:
# Reusing TensorBoard on port 6011 (pid 43756), started 18:38:42 ago. (Use '!kill 43756' to kill it.)
#       <iframe id="tensorboard-frame-f40ea72cc15fd04" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f40ea72cc15fd04");
#           const url = new URL("/", window.location);
#           const port = 6011;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
